# %%
import pandas as pd 
df = pd.read_json('lejuandetails.jsonl', lines=True)
df
# Out:
#                                                  base  \
# 0   {'case_record_list': [{'end_time': '2027-10-28...
# 1   {'case_record_list': [{'end_time': '2027-12-31...
# 2   {'axhl': '1', 'case_record_list': [{'end_time'...
# 3   {'case_record_list': [{'end_time': '2026-12-31...
# 4   {'case_record_list': [{'end_time': '2039-12-31...
# 5   {'case_record_list': [{'end_time': '2028-09-30...
# 6   {'axhl': '1', 'case_record_list': [{'end_time'...
# 7   {'axhl': '1', 'case_record_list': [{'end_time'...
# 8   {'case_record_list': [{'end_time': '2029-02-15...
# 9   {'case_record_list': [{'end_time': '2026-05-08...
# 10  {'case_record_list': [{'end_time': '2029-03-30...
# 11  {'case_record_list': [{'end_time': '2079-12-29...
# 12  {'case_record_list': [{'end_time': '2027-10-31...
# 13  {'case_record_list': [{'end_time': '2027-04-09...
# 14  {'axhl': '1', 'case_record_list': [{'end_time'...
# 15  {'case_record_list': [{'end_time': '2026-12-31...
# ...

# %%
df['image_urls'].apply(lambda x: len(x) if isinstance(x, list) else 0).describe()
# Out:
# count    18.000000
# mean      9.944444
# std       3.403670
# min       5.000000
# 25%       6.250000
# 50%      10.000000
# 75%      13.000000
# max      15.000000
# Name: image_urls, dtype: float64
